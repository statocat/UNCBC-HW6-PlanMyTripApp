# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

#import pretty print package and set up pretty printer
import pprint as pprint
pp = pprint.PrettyPrinter(indent = 4, width =80, compact = False)

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Deliverable 6.1.3
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,2000)
lngs = np.random.uniform(-90,90,2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats,lngs)

# Add the latitudes and longitudes to a list
coordinates= list(lats_lngs)

#compact way
# coordinates = = list(zip(np.random.uniform(-90,90,2000),np.random.uniform(-90,90,2000)))

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Deliverable 6.1.4
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for i in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(i[0],i[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 775

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
#Deliverable 6.1.5

# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import ow_key

# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=' + ow_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Deliverable 6.1.6
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_weather['sys']['country'],
                          "Lat": city_weather['coord']['lat'],
                          "Lng": city_weather['coord']['lon'],
                          "Max Temp": city_weather['main']['temp_max'],
                          "Humidity": city_weather['main']['humidity'] ,
                          "Cloudiness": city_weather['clouds']['all'],
                          "Wind Speed": city_weather['wind']['speed'],
                          "Current Description": city_weather['weather'][0]['description'],
                          #"Date": datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                          })
        print("City found")
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tessalit
# City found
# Processing Record 2 of Set 1 | upernavik
# City found
# Processing Record 3 of Set 1 | cape town
# City found
# Processing Record 4 of Set 1 | los llanos de aridane
# City found
# Processing Record 5 of Set 1 | longyearbyen
# City found
# Processing Record 6 of Set 1 | sawakin
# City found
# Processing Record 7 of Set 1 | georgetown
# City found
# Processing Record 8 of Set 1 | qaanaaq
# City found
# Processing Record 9 of Set 1 | comodoro rivadavia
# City found
# Processing Record 10 of Set 1 | carnarvon
# City found
# Processing Record 11 of Set 1 | lebu
# City found
# Processing Record 12 of Set 1 | punta arenas
# City found
# Processing Record 13 of Set 1 | banda aceh
# City found
# Processing Record 14 of Set 1 | granard
# City found
# Processing Record 15 of Set 1 | qaqortoq
# City found
# Processing Record 16 of Set 1 | hermanus
# City found
# Processing Record 17 of Set 1 | narsaq
# City found
# Processing Record 18 of Set 1 | ushuaia
# City found
# Processing Record 19 of Set 1 | manacapuru
# City found
# Processing Record 20 of Set 1 | cockburn town
# City found
# Processing Record 21 of Set 1 | asyut
# City found
# Processing Record 22 of Set 1 | aubagne
# City found
# Processing Record 23 of Set 1 | alta floresta
# City found
# Processing Record 24 of Set 1 | qazvin
# City found
# Processing Record 25 of Set 1 | dikson
# City found
# Processing Record 26 of Set 1 | clyde river
# City found
# Processing Record 27 of Set 1 | tasiilaq
# City found
# Processing Record 28 of Set 1 | port elizabeth
# City found
# Processing Record 29 of Set 1 | cidreira
# City found
# Processing Record 30 of Set 1 | quatre cocos
# City found
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | turayf
# City found
# Processing Record 33 of Set 1 | lenauheim
# City found
# Processing Record 34 of Set 1 | saint-francois
# City found
# Processing Record 35 of Set 1 | kachikau
# City not found. Skipping...
# Processing Record 36 of Set 1 | lamu
# City found
# Processing Record 37 of Set 1 | manicore
# City found
# Processing Record 38 of Set 1 | adrar
# City found
# Processing Record 39 of Set 1 | praia
# City found
# Processing Record 40 of Set 1 | abu dhabi
# City found
# Processing Record 41 of Set 1 | mar del plata
# City found
# Processing Record 42 of Set 1 | saint-philippe
# City found
# Processing Record 43 of Set 1 | natal
# City found
# Processing Record 44 of Set 1 | san felipe
# City found
# Processing Record 45 of Set 1 | ipanema
# City found
# Processing Record 46 of Set 1 | jurm
# City found
# Processing Record 47 of Set 1 | ribeira grande
# City found
# Processing Record 48 of Set 1 | yizhivtsi
# City found
# Processing Record 49 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 1 | vila vicosa
# City found
# Processing Record 1 of Set 2 | matara
# City found
# Processing Record 2 of Set 2 | ilulissat
# City found
# Processing Record 3 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 4 of Set 2 | victoria
# City found
# Processing Record 5 of Set 2 | alghero
# City found
# Processing Record 6 of Set 2 | jamestown
# City found
# Processing Record 7 of Set 2 | mahibadhoo
# City found
# Processing Record 8 of Set 2 | labrea
# City found
# Processing Record 9 of Set 2 | busselton
# City found
# Processing Record 10 of Set 2 | sistranda
# City found
# Processing Record 11 of Set 2 | iqaluit
# City found
# Processing Record 12 of Set 2 | anzio
# City found
# Processing Record 13 of Set 2 | georgiyevka
# City found
# Processing Record 14 of Set 2 | port alfred
# City found
# Processing Record 15 of Set 2 | saint george
# City found
# Processing Record 16 of Set 2 | bolu
# City found
# Processing Record 17 of Set 2 | forestville
# City found
# Processing Record 18 of Set 2 | talmenka
# City found
# Processing Record 19 of Set 2 | dingle
# City found
# Processing Record 20 of Set 2 | hambantota
# City found
# Processing Record 21 of Set 2 | lagoa
# City found
# Processing Record 22 of Set 2 | quelimane
# City found
# Processing Record 23 of Set 2 | benguela
# City found
# Processing Record 24 of Set 2 | derzhavinsk
# City found
# Processing Record 25 of Set 2 | port-gentil
# City found
# Processing Record 26 of Set 2 | ambilobe
# City found
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | kruisfontein
# City found
# Processing Record 29 of Set 2 | naryan-mar
# City found
# Processing Record 30 of Set 2 | east london
# City found
# Processing Record 31 of Set 2 | chuy
# City found
# Processing Record 32 of Set 2 | arlit
# City found
# Processing Record 33 of Set 2 | virpur
# City found
# Processing Record 34 of Set 2 | vardo
# City found
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 2 | oranjemund
# City found
# Processing Record 39 of Set 2 | beloha
# City found
# Processing Record 40 of Set 2 | azul
# City found
# Processing Record 41 of Set 2 | batticaloa
# City found
# Processing Record 42 of Set 2 | noyabrsk
# City found
# Processing Record 43 of Set 2 | bredasdorp
# City found
# Processing Record 44 of Set 2 | zaterechnyy
# City found
# Processing Record 45 of Set 2 | odweyne
# City found
# Processing Record 46 of Set 2 | alto araguaia
# City found
# Processing Record 47 of Set 2 | sao joao da barra
# City found
# Processing Record 48 of Set 2 | paamiut
# City found
# Processing Record 49 of Set 2 | malente
# City found
# Processing Record 50 of Set 2 | atar
# City found
# Processing Record 1 of Set 3 | laguna de perlas
# City found
# Processing Record 2 of Set 3 | malanje
# City found
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | arraial do cabo
# City found
# Processing Record 5 of Set 3 | souillac
# City found
# Processing Record 6 of Set 3 | torbay
# City found
# Processing Record 7 of Set 3 | saldanha
# City found
# Processing Record 8 of Set 3 | sinnamary
# City found
# Processing Record 9 of Set 3 | fomboni
# City found
# Processing Record 10 of Set 3 | kiruna
# City found
# Processing Record 11 of Set 3 | hofn
# City found
# Processing Record 12 of Set 3 | bay roberts
# City found
# Processing Record 13 of Set 3 | aswan
# City found
# Processing Record 14 of Set 3 | talcahuano
# City found
# Processing Record 15 of Set 3 | sassandra
# City found
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | pangnirtung
# City found
# Processing Record 18 of Set 3 | adiake
# City found
# Processing Record 19 of Set 3 | trairi
# City found
# Processing Record 20 of Set 3 | dubasari
# City found
# Processing Record 21 of Set 3 | san cristobal
# City found
# Processing Record 22 of Set 3 | kavaratti
# City found
# Processing Record 23 of Set 3 | campbellsville
# City found
# Processing Record 24 of Set 3 | bardiyah
# City found
# Processing Record 25 of Set 3 | keighley
# City found
# Processing Record 26 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 3 | laguna
# City found
# Processing Record 28 of Set 3 | bambous virieux
# City found
# Processing Record 29 of Set 3 | grindavik
# City found
# Processing Record 30 of Set 3 | liverpool
# City found
# Processing Record 31 of Set 3 | chokwe
# City found
# Processing Record 32 of Set 3 | cururupu
# City found
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | kutum
# City found
# Processing Record 35 of Set 3 | mondeville
# City found
# Processing Record 36 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 3 | santa lucia
# City found
# Processing Record 38 of Set 3 | bonavista
# City found
# Processing Record 39 of Set 3 | aranos
# City found
# Processing Record 40 of Set 3 | aksu
# City found
# Processing Record 41 of Set 3 | panjab
# City found
# Processing Record 42 of Set 3 | ostrovnoy
# City found
# Processing Record 43 of Set 3 | saint-joseph
# City found
# Processing Record 44 of Set 3 | salalah
# City found
# Processing Record 45 of Set 3 | omboue
# City found
# Processing Record 46 of Set 3 | kaniama
# City found
# Processing Record 47 of Set 3 | namibe
# City found
# Processing Record 48 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 3 | galle
# City found
# Processing Record 50 of Set 3 | vila franca do campo
# City found
# Processing Record 1 of Set 4 | koungou
# City found
# Processing Record 2 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 4 | nanortalik
# City found
# Processing Record 4 of Set 4 | miraflores
# City found
# Processing Record 5 of Set 4 | puerto escondido
# City found
# Processing Record 6 of Set 4 | xuddur
# City found
# Processing Record 7 of Set 4 | ponta delgada
# City found
# Processing Record 8 of Set 4 | yarim
# City found
# Processing Record 9 of Set 4 | hithadhoo
# City found
# Processing Record 10 of Set 4 | olafsvik
# City found
# Processing Record 11 of Set 4 | chadiza
# City found
# Processing Record 12 of Set 4 | cham
# City found
# Processing Record 13 of Set 4 | monrovia
# City found
# Processing Record 14 of Set 4 | ayagoz
# City found
# Processing Record 15 of Set 4 | antsohihy
# City found
# Processing Record 16 of Set 4 | san carlos
# City found
# Processing Record 17 of Set 4 | estelle
# City found
# Processing Record 18 of Set 4 | turukhansk
# City found
# Processing Record 19 of Set 4 | rawson
# City found
# Processing Record 20 of Set 4 | zakupne
# City found
# Processing Record 21 of Set 4 | abalak
# City found
# Processing Record 22 of Set 4 | neuquen
# City found
# Processing Record 23 of Set 4 | diego de almagro
# City found
# Processing Record 24 of Set 4 | soyo
# City found
# Processing Record 25 of Set 4 | rognan
# City found
# Processing Record 26 of Set 4 | ponta do sol
# City found
# Processing Record 27 of Set 4 | kasra
# City not found. Skipping...
# Processing Record 28 of Set 4 | berbera
# City found
# Processing Record 29 of Set 4 | klaksvik
# City found
# Processing Record 30 of Set 4 | santa isabel do rio negro
# City found
# Processing Record 31 of Set 4 | jacqueville
# City found
# Processing Record 32 of Set 4 | mut
# City found
# Processing Record 33 of Set 4 | hit
# City found
# Processing Record 34 of Set 4 | saint leonard
# City found
# Processing Record 35 of Set 4 | maceio
# City found
# Processing Record 36 of Set 4 | normandin
# City found
# Processing Record 37 of Set 4 | mabaruma
# City found
# Processing Record 38 of Set 4 | nouakchott
# City found
# Processing Record 39 of Set 4 | conde
# City found
# Processing Record 40 of Set 4 | rio tercero
# City found
# Processing Record 41 of Set 4 | nalut
# City found
# Processing Record 42 of Set 4 | cozumel
# City found
# Processing Record 43 of Set 4 | sisimiut
# City found
# Processing Record 44 of Set 4 | goderich
# City found
# Processing Record 45 of Set 4 | sao filipe
# City found
# Processing Record 46 of Set 4 | castro
# City found
# Processing Record 47 of Set 4 | nizwa
# City found
# Processing Record 48 of Set 4 | vorkuta
# City found
# Processing Record 49 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 4 | norden
# City found
# Processing Record 1 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 5 | moussoro
# City found
# Processing Record 3 of Set 5 | mandal
# City found
# Processing Record 4 of Set 5 | ayacucho
# City found
# Processing Record 5 of Set 5 | sao gabriel da cachoeira
# City found
# Processing Record 6 of Set 5 | grand gaube
# City found
# Processing Record 7 of Set 5 | kikwit
# City found
# Processing Record 8 of Set 5 | nassau
# City found
# Processing Record 9 of Set 5 | sorkjosen
# City found
# Processing Record 10 of Set 5 | luderitz
# City found
# Processing Record 11 of Set 5 | umm kaddadah
# City found
# Processing Record 12 of Set 5 | puerto carreno
# City found
# Processing Record 13 of Set 5 | riesa
# City found
# Processing Record 14 of Set 5 | butler
# City found
# Processing Record 15 of Set 5 | yenagoa
# City found
# Processing Record 16 of Set 5 | hosdurga
# City found
# Processing Record 17 of Set 5 | sete
# City found
# Processing Record 18 of Set 5 | farafangana
# City found
# Processing Record 19 of Set 5 | ostersund
# City found
# Processing Record 20 of Set 5 | moyale
# City found
# Processing Record 21 of Set 5 | buta
# City found
# Processing Record 22 of Set 5 | lambare
# City found
# Processing Record 23 of Set 5 | gewane
# City found
# Processing Record 24 of Set 5 | manaus
# City found
# Processing Record 25 of Set 5 | puerto madryn
# City found
# Processing Record 26 of Set 5 | sarankhola
# City found
# Processing Record 27 of Set 5 | mayenne
# City found
# Processing Record 28 of Set 5 | krasnoselkup
# City found
# Processing Record 29 of Set 5 | nikel
# City found
# Processing Record 30 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 31 of Set 5 | jacareacanga
# City found
# Processing Record 32 of Set 5 | jawhar
# City found
# Processing Record 33 of Set 5 | havre-saint-pierre
# City found
# Processing Record 34 of Set 5 | olinda
# City found
# Processing Record 35 of Set 5 | george town
# City found
# Processing Record 36 of Set 5 | troitskoye
# City found
# Processing Record 37 of Set 5 | iralaya
# City found
# Processing Record 38 of Set 5 | warmbad
# City found
# Processing Record 39 of Set 5 | saint-augustin
# City found
# Processing Record 40 of Set 5 | bathsheba
# City found
# Processing Record 41 of Set 5 | kyzyl-suu
# City found
# Processing Record 42 of Set 5 | goedereede
# City found
# Processing Record 43 of Set 5 | copiapo
# City found
# Processing Record 44 of Set 5 | mutum
# City found
# Processing Record 45 of Set 5 | maniitsoq
# City found
# Processing Record 46 of Set 5 | basoko
# City found
# Processing Record 47 of Set 5 | zemio
# City found
# Processing Record 48 of Set 5 | bouca
# City found
# Processing Record 49 of Set 5 | mahebourg
# City found
# Processing Record 50 of Set 5 | waidhofen
# City found
# Processing Record 1 of Set 6 | leh
# City found
# Processing Record 2 of Set 6 | wattegama
# City found
# Processing Record 3 of Set 6 | ormara
# City found
# Processing Record 4 of Set 6 | balkanabat
# City found
# Processing Record 5 of Set 6 | bignona
# City found
# Processing Record 6 of Set 6 | bull savanna
# City found
# Processing Record 7 of Set 6 | arvi
# City found
# Processing Record 8 of Set 6 | chicama
# City found
# Processing Record 9 of Set 6 | muzhi
# City found
# Processing Record 10 of Set 6 | devrek
# City found
# Processing Record 11 of Set 6 | romny
# City found
# Processing Record 12 of Set 6 | bodden town
# City found
# Processing Record 13 of Set 6 | lichinga
# City found
# Processing Record 14 of Set 6 | praia da vitoria
# City found
# Processing Record 15 of Set 6 | lons
# City found
# Processing Record 16 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 6 | aksarka
# City found
# Processing Record 18 of Set 6 | skibbereen
# City found
# Processing Record 19 of Set 6 | high rock
# City found
# Processing Record 20 of Set 6 | saint andrews
# City found
# Processing Record 21 of Set 6 | ciego de avila
# City found
# Processing Record 22 of Set 6 | vasai
# City found
# Processing Record 23 of Set 6 | minsk
# City found
# Processing Record 24 of Set 6 | port blair
# City found
# Processing Record 25 of Set 6 | marathon
# City found
# Processing Record 26 of Set 6 | matagami
# City found
# Processing Record 27 of Set 6 | saint anthony
# City found
# Processing Record 28 of Set 6 | poltava
# City found
# Processing Record 29 of Set 6 | shelburne
# City found
# Processing Record 30 of Set 6 | sumbe
# City found
# Processing Record 31 of Set 6 | saint-pierre
# City found
# Processing Record 32 of Set 6 | goure
# City found
# Processing Record 33 of Set 6 | sorland
# City found
# Processing Record 34 of Set 6 | timra
# City found
# Processing Record 35 of Set 6 | hamilton
# City found
# Processing Record 36 of Set 6 | moss point
# City found
# Processing Record 37 of Set 6 | havelock
# City found
# Processing Record 38 of Set 6 | bama
# City found
# Processing Record 39 of Set 6 | andreapol
# City found
# Processing Record 40 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 6 | leeuwarden
# City found
# Processing Record 42 of Set 6 | vangaindrano
# City found
# Processing Record 43 of Set 6 | nizhniy baskunchak
# City found
# Processing Record 44 of Set 6 | beitbridge
# City found
# Processing Record 45 of Set 6 | sandy bay
# City found
# Processing Record 46 of Set 6 | rosetta
# City found
# Processing Record 47 of Set 6 | hundested
# City found
# Processing Record 48 of Set 6 | lisala
# City found
# Processing Record 49 of Set 6 | arani
# City found
# Processing Record 50 of Set 6 | kuytun
# City found
# Processing Record 1 of Set 7 | candolim
# City found
# Processing Record 2 of Set 7 | guspini
# City found
# Processing Record 3 of Set 7 | gat
# City found
# Processing Record 4 of Set 7 | morristown
# City found
# Processing Record 5 of Set 7 | sept-iles
# City found
# Processing Record 6 of Set 7 | gamba
# City found
# Processing Record 7 of Set 7 | abu zabad
# City found
# Processing Record 8 of Set 7 | kjollefjord
# City found
# Processing Record 9 of Set 7 | khanpur
# City found
# Processing Record 10 of Set 7 | alexandroupoli
# City found
# Processing Record 11 of Set 7 | scalloway
# City not found. Skipping...
# Processing Record 12 of Set 7 | rozhyshche
# City found
# Processing Record 13 of Set 7 | melilla
# City found
# Processing Record 14 of Set 7 | rafai
# City found
# Processing Record 15 of Set 7 | eyl
# City found
# Processing Record 16 of Set 7 | padilla
# City found
# Processing Record 17 of Set 7 | birin
# City found
# Processing Record 18 of Set 7 | marrakesh
# City found
# Processing Record 19 of Set 7 | scarborough
# City found
# Processing Record 20 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 21 of Set 7 | zabid
# City found
# Processing Record 22 of Set 7 | valparaiso
# City found
# Processing Record 23 of Set 7 | panama city
# City found
# Processing Record 24 of Set 7 | carutapera
# City found
# Processing Record 25 of Set 7 | dudinka
# City found
# Processing Record 26 of Set 7 | geraldton
# City found
# Processing Record 27 of Set 7 | hobyo
# City found
# Processing Record 28 of Set 7 | plymouth
# City found
# Processing Record 29 of Set 7 | caninde
# City found
# Processing Record 30 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 7 | jiwani
# City found
# Processing Record 32 of Set 7 | beisfjord
# City found
# Processing Record 33 of Set 7 | santa vitoria do palmar
# City found
# Processing Record 34 of Set 7 | bissora
# City found
# Processing Record 35 of Set 7 | touros
# City found
# Processing Record 36 of Set 7 | puerto leguizamo
# City found
# Processing Record 37 of Set 7 | cobija
# City found
# Processing Record 38 of Set 7 | abha
# City found
# Processing Record 39 of Set 7 | henties bay
# City found
# Processing Record 40 of Set 7 | havant
# City found
# Processing Record 41 of Set 7 | zile
# City found
# Processing Record 42 of Set 7 | acarau
# City found
# Processing Record 43 of Set 7 | kuusamo
# City found
# Processing Record 44 of Set 7 | mineros
# City found
# Processing Record 45 of Set 7 | bilma
# City found
# Processing Record 46 of Set 7 | marsh harbour
# City found
# Processing Record 47 of Set 7 | puerto baquerizo moreno
# City found
# Processing Record 48 of Set 7 | amapa
# City found
# Processing Record 49 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 50 of Set 7 | nanga eboko
# City found
# Processing Record 1 of Set 8 | santiago del estero
# City found
# Processing Record 2 of Set 8 | matai
# City found
# Processing Record 3 of Set 8 | santa cruz
# City found
# Processing Record 4 of Set 8 | imbituba
# City found
# Processing Record 5 of Set 8 | iskateley
# City found
# Processing Record 6 of Set 8 | nortelandia
# City found
# Processing Record 7 of Set 8 | korla
# City found
# Processing Record 8 of Set 8 | kazanskaya
# City found
# Processing Record 9 of Set 8 | taltal
# City found
# Processing Record 10 of Set 8 | mount vernon
# City found
# Processing Record 11 of Set 8 | landeck
# City found
# Processing Record 12 of Set 8 | aguimes
# City found
# Processing Record 13 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 14 of Set 8 | punahana
# City found
# Processing Record 15 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 16 of Set 8 | rize
# City found
# Processing Record 17 of Set 8 | margate
# City found
# Processing Record 18 of Set 8 | albany
# City found
# Processing Record 19 of Set 8 | yar-sale
# City found
# Processing Record 20 of Set 8 | cumana
# City found
# Processing Record 21 of Set 8 | mao
# City found
# Processing Record 22 of Set 8 | muros
# City found
# Processing Record 23 of Set 8 | jeremie
# City found
# Processing Record 24 of Set 8 | nuuk
# City found
# Processing Record 25 of Set 8 | ivybridge
# City found
# Processing Record 26 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 27 of Set 8 | riyadh
# City found
# Processing Record 28 of Set 8 | rajnagar
# City found
# Processing Record 29 of Set 8 | rawa mazowiecka
# City found
# Processing Record 30 of Set 8 | riviere-au-renard
# City found
# Processing Record 31 of Set 8 | sambava
# City found
# Processing Record 32 of Set 8 | aripuana
# City found
# Processing Record 33 of Set 8 | pimenta bueno
# City found
# Processing Record 34 of Set 8 | bam
# City found
# Processing Record 35 of Set 8 | nizhnevartovsk
# City found
# Processing Record 36 of Set 8 | tupa
# City found
# Processing Record 37 of Set 8 | ferme-neuve
# City found
# Processing Record 38 of Set 8 | fillan
# City found
# Processing Record 39 of Set 8 | concordia
# City found
# Processing Record 40 of Set 8 | trinidad
# City found
# Processing Record 41 of Set 8 | bluefields
# City found
# Processing Record 42 of Set 8 | bonito
# City found
# Processing Record 43 of Set 8 | iguape
# City found
# Processing Record 44 of Set 8 | hinesville
# City found
# Processing Record 45 of Set 8 | talnakh
# City found
# Processing Record 46 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 47 of Set 8 | mwinilunga
# City found
# Processing Record 48 of Set 8 | marzuq
# City found
# Processing Record 49 of Set 8 | chapais
# City found
# Processing Record 50 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 1 of Set 9 | kattivakkam
# City found
# Processing Record 2 of Set 9 | gashua
# City found
# Processing Record 3 of Set 9 | mecca
# City found
# Processing Record 4 of Set 9 | lasa
# City found
# Processing Record 5 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 9 | kundla
# City found
# Processing Record 7 of Set 9 | tulsipur
# City found
# Processing Record 8 of Set 9 | rocha
# City found
# Processing Record 9 of Set 9 | vestmanna
# City found
# Processing Record 10 of Set 9 | distraccion
# City found
# Processing Record 11 of Set 9 | tarko-sale
# City found
# Processing Record 12 of Set 9 | bubaque
# City found
# Processing Record 13 of Set 9 | burica
# City not found. Skipping...
# Processing Record 14 of Set 9 | colares
# City found
# Processing Record 15 of Set 9 | langevag
# City found
# Processing Record 16 of Set 9 | abu kamal
# City found
# Processing Record 17 of Set 9 | lakota
# City found
# Processing Record 18 of Set 9 | muisne
# City found
# Processing Record 19 of Set 9 | antofagasta
# City found
# Processing Record 20 of Set 9 | casma
# City found
# Processing Record 21 of Set 9 | kamenka
# City found
# Processing Record 22 of Set 9 | aromashevo
# City found
# Processing Record 23 of Set 9 | vila velha
# City found
# Processing Record 24 of Set 9 | chik
# City found
# Processing Record 25 of Set 9 | frejlev
# City found
# Processing Record 26 of Set 9 | puerto cabezas
# City found
# Processing Record 27 of Set 9 | nioro
# City found
# Processing Record 28 of Set 9 | jamame
# City found
# Processing Record 29 of Set 9 | awjilah
# City found
# Processing Record 30 of Set 9 | come
# City found
# Processing Record 31 of Set 9 | coquimbo
# City found
# Processing Record 32 of Set 9 | xilagani
# City found
# Processing Record 33 of Set 9 | ares
# City found
# Processing Record 34 of Set 9 | atakpame
# City found
# Processing Record 35 of Set 9 | itarema
# City found
# Processing Record 36 of Set 9 | saquena
# City found
# Processing Record 37 of Set 9 | thompson
# City found
# Processing Record 38 of Set 9 | bereda
# City found
# Processing Record 39 of Set 9 | ballina
# City found
# Processing Record 40 of Set 9 | marawi
# City found
# Processing Record 41 of Set 9 | ghanzi
# City found
# Processing Record 42 of Set 9 | ajdabiya
# City found
# Processing Record 43 of Set 9 | cap malheureux
# City found
# Processing Record 44 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 9 | muborak
# City found
# Processing Record 46 of Set 9 | baboua
# City not found. Skipping...
# Processing Record 47 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 9 | zhanaozen
# City found
# Processing Record 49 of Set 9 | kabelvag
# City found
# Processing Record 50 of Set 9 | goksun
# City found
# Processing Record 1 of Set 10 | maragogi
# City found
# Processing Record 2 of Set 10 | harper
# City found
# Processing Record 3 of Set 10 | iracoubo
# City found
# Processing Record 4 of Set 10 | platanos
# City found
# Processing Record 5 of Set 10 | tombouctou
# City found
# Processing Record 6 of Set 10 | yarmouth
# City found
# Processing Record 7 of Set 10 | tabas
# City found
# Processing Record 8 of Set 10 | diapaga
# City found
# Processing Record 9 of Set 10 | vestmannaeyjar
# City found
# Processing Record 10 of Set 10 | ladario
# City found
# Processing Record 11 of Set 10 | agadez
# City found
# Processing Record 12 of Set 10 | japura
# City found
# Processing Record 13 of Set 10 | sosua
# City found
# Processing Record 14 of Set 10 | rio verde de mato grosso
# City found
# Processing Record 15 of Set 10 | lusambo
# City found
# Processing Record 16 of Set 10 | roald
# City found
# Processing Record 17 of Set 10 | ashdod
# City found
# Processing Record 18 of Set 10 | halifax
# City found
# Processing Record 19 of Set 10 | necochea
# City found
# Processing Record 20 of Set 10 | minab
# City found
# Processing Record 21 of Set 10 | saint-leu
# City found
# Processing Record 22 of Set 10 | joshimath
# City found
# Processing Record 23 of Set 10 | tres passos
# City found
# Processing Record 24 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 25 of Set 10 | san martin
# City found
# Processing Record 26 of Set 10 | axim
# City found
# Processing Record 27 of Set 10 | bandarbeyla
# City found
# Processing Record 28 of Set 10 | luxor
# City found
# Processing Record 29 of Set 10 | saint-georges
# City found
# Processing Record 30 of Set 10 | tazovskiy
# City found
# Processing Record 31 of Set 10 | frolishchi
# City found
# Processing Record 32 of Set 10 | dawlatabad
# City found
# Processing Record 33 of Set 10 | tiznit
# City found
# Processing Record 34 of Set 10 | miranda
# City found
# Processing Record 35 of Set 10 | pisco
# City found
# Processing Record 36 of Set 10 | oistins
# City found
# Processing Record 37 of Set 10 | caravelas
# City found
# Processing Record 38 of Set 10 | lima
# City found
# Processing Record 39 of Set 10 | oeiras do para
# City found
# Processing Record 40 of Set 10 | orumiyeh
# City found
# Processing Record 41 of Set 10 | portmore
# City found
# Processing Record 42 of Set 10 | trelleborg
# City found
# Processing Record 43 of Set 10 | nyrob
# City found
# Processing Record 44 of Set 10 | sarkand
# City found
# Processing Record 45 of Set 10 | nantucket
# City found
# Processing Record 46 of Set 10 | sarai
# City found
# Processing Record 47 of Set 10 | moose factory
# City found
# Processing Record 48 of Set 10 | sainte-suzanne
# City found
# Processing Record 49 of Set 10 | santa cruz de tenerife
# City found
# Processing Record 50 of Set 10 | biltine
# City found
# Processing Record 1 of Set 11 | cruzeiro do sul
# City found
# Processing Record 2 of Set 11 | nsoko
# City found
# Processing Record 3 of Set 11 | koslan
# City found
# Processing Record 4 of Set 11 | huarmey
# City found
# Processing Record 5 of Set 11 | san carlos de bariloche
# City found
# Processing Record 6 of Set 11 | usinsk
# City found
# Processing Record 7 of Set 11 | burton
# City found
# Processing Record 8 of Set 11 | santa rosa
# City found
# Processing Record 9 of Set 11 | malaya serdoba
# City found
# Processing Record 10 of Set 11 | jacksonville
# City found
# Processing Record 11 of Set 11 | miracema do tocantins
# City found
# Processing Record 12 of Set 11 | holme
# City found
# Processing Record 13 of Set 11 | bengkulu
# City found
# Processing Record 14 of Set 11 | belmonte
# City found
# Processing Record 15 of Set 11 | oppdal
# City found
# Processing Record 16 of Set 11 | carauari
# City found
# Processing Record 17 of Set 11 | bejar
# City found
# Processing Record 18 of Set 11 | nador
# City found
# Processing Record 19 of Set 11 | sao jose da coroa grande
# City found
# Processing Record 20 of Set 11 | chimore
# City found
# Processing Record 21 of Set 11 | sabha
# City found
# Processing Record 22 of Set 11 | raudeberg
# City found
# Processing Record 23 of Set 11 | mengen
# City found
# Processing Record 24 of Set 11 | tobol
# City found
# Processing Record 25 of Set 11 | codrington
# City found
# Processing Record 26 of Set 11 | maltahohe
# City found
# Processing Record 27 of Set 11 | zhezkazgan
# City found
# Processing Record 28 of Set 11 | kem
# City found
# Processing Record 29 of Set 11 | hauterive
# City found
# Processing Record 30 of Set 11 | lobva
# City found
# Processing Record 31 of Set 11 | buraydah
# City found
# Processing Record 32 of Set 11 | boralday
# City found
# Processing Record 33 of Set 11 | uinskoye
# City found
# Processing Record 34 of Set 11 | kupino
# City found
# Processing Record 35 of Set 11 | marystown
# City found
# Processing Record 36 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 37 of Set 11 | presidencia roque saenz pena
# City found
# Processing Record 38 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 39 of Set 11 | kantunilkin
# City found
# Processing Record 40 of Set 11 | trofors
# City found
# Processing Record 41 of Set 11 | manjacaze
# City found
# Processing Record 42 of Set 11 | cayenne
# City found
# Processing Record 43 of Set 11 | mandera
# City found
# Processing Record 44 of Set 11 | pasni
# City found
# Processing Record 45 of Set 11 | ivanava
# City found
# Processing Record 46 of Set 11 | oxapampa
# City found
# Processing Record 47 of Set 11 | plettenberg bay
# City found
# Processing Record 48 of Set 11 | taoudenni
# City found
# Processing Record 49 of Set 11 | lodwar
# City found
# Processing Record 50 of Set 11 | lodja
# City found
# Processing Record 1 of Set 12 | ariquemes
# City found
# Processing Record 2 of Set 12 | menongue
# City found
# Processing Record 3 of Set 12 | gidole
# City found
# Processing Record 4 of Set 12 | sechura
# City found
# Processing Record 5 of Set 12 | selma
# City found
# Processing Record 6 of Set 12 | monastyrshchina
# City found
# Processing Record 7 of Set 12 | siddapur
# City found
# Processing Record 8 of Set 12 | hammerfest
# City found
# Processing Record 9 of Set 12 | truro
# City found
# Processing Record 10 of Set 12 | puerto del rosario
# City found
# Processing Record 11 of Set 12 | husavik
# City found
# Processing Record 12 of Set 12 | salinopolis
# City found
# Processing Record 13 of Set 12 | coihaique
# City found
# Processing Record 14 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 12 | paita
# City found
# Processing Record 16 of Set 12 | varnavino
# City found
# Processing Record 17 of Set 12 | urdoma
# City found
# Processing Record 18 of Set 12 | chinna salem
# City found
# Processing Record 19 of Set 12 | sao felix do xingu
# City found
# Processing Record 20 of Set 12 | mehnagar
# City found
# Processing Record 21 of Set 12 | camocim
# City found
# Processing Record 22 of Set 12 | rio gallegos
# City found
# Processing Record 23 of Set 12 | nouadhibou
# City found
# Processing Record 24 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 12 | keti bandar
# City found
# Processing Record 26 of Set 12 | vila do maio
# City found
# Processing Record 27 of Set 12 | jalaun
# City found
# Processing Record 28 of Set 12 | kirkuk
# City found
# Processing Record 29 of Set 12 | pechora
# City found
# Processing Record 30 of Set 12 | inirida
# City found
# Processing Record 31 of Set 12 | syamzha
# City found
# Processing Record 32 of Set 12 | kumbo
# City found
# Processing Record 33 of Set 12 | maputo
# City found
# Processing Record 34 of Set 12 | takoradi
# City found
# Processing Record 35 of Set 12 | lubao
# City found
# Processing Record 36 of Set 12 | salamiyah
# City found
# Processing Record 37 of Set 12 | serta
# City found
# Processing Record 38 of Set 12 | bonfim
# City found
# Processing Record 39 of Set 12 | ust-tsilma
# City found
# Processing Record 40 of Set 12 | corinto
# City found
# Processing Record 41 of Set 12 | qandala
# City found
# Processing Record 42 of Set 12 | camacha
# City found
# Processing Record 43 of Set 12 | le port
# City found
# Processing Record 44 of Set 12 | saurimo
# City found
# Processing Record 45 of Set 12 | ugoofaaru
# City found
# Processing Record 46 of Set 12 | pittsfield
# City found
# Processing Record 47 of Set 12 | pirapemas
# City found
# Processing Record 48 of Set 12 | wolomin
# City not found. Skipping...
# Processing Record 49 of Set 12 | cheremukhovo
# City found
# Processing Record 50 of Set 12 | guane
# City found
# Processing Record 1 of Set 13 | paracatu
# City found
# Processing Record 2 of Set 13 | altamira
# City found
# Processing Record 3 of Set 13 | alice
# City found
# Processing Record 4 of Set 13 | evanton
# City found
# Processing Record 5 of Set 13 | salinas
# City found
# Processing Record 6 of Set 13 | opuwo
# City found
# Processing Record 7 of Set 13 | buenavista
# City found
# Processing Record 8 of Set 13 | mantua
# City found
# Processing Record 9 of Set 13 | kokkola
# City found
# Processing Record 10 of Set 13 | mende
# City found
# Processing Record 11 of Set 13 | ginir
# City found
# Processing Record 12 of Set 13 | chegutu
# City found
# Processing Record 13 of Set 13 | grootfontein
# City found
# Processing Record 14 of Set 13 | portachuelo
# City found
# Processing Record 15 of Set 13 | walvis bay
# City found
# Processing Record 16 of Set 13 | aasiaat
# City found
# Processing Record 17 of Set 13 | ape
# City found
# Processing Record 18 of Set 13 | royan
# City found
# Processing Record 19 of Set 13 | merritt island
# City found
# Processing Record 20 of Set 13 | alta gracia
# City found
# Processing Record 21 of Set 13 | bolobo
# City found
# Processing Record 22 of Set 13 | kano
# City found
# Processing Record 23 of Set 13 | beckley
# City found
# Processing Record 24 of Set 13 | constitucion
# City found
# Processing Record 25 of Set 13 | atasu
# City found
# Processing Record 26 of Set 13 | sur
# City found
# Processing Record 27 of Set 13 | brae
# City found
# Processing Record 28 of Set 13 | murray
# City found
# Processing Record 29 of Set 13 | tamandare
# City found
# Processing Record 30 of Set 13 | ramotswa
# City found
# Processing Record 31 of Set 13 | karla
# City found
# Processing Record 32 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 13 | aruppukkottai
# City found
# Processing Record 34 of Set 13 | vedaranniyam
# City not found. Skipping...
# Processing Record 35 of Set 13 | pirai do sul
# City found
# Processing Record 36 of Set 13 | bonthe
# City found
# Processing Record 37 of Set 13 | ayni
# City found
# Processing Record 38 of Set 13 | staszow
# City found
# Processing Record 39 of Set 13 | jalu
# City found
# Processing Record 40 of Set 13 | kapuskasing
# City found
# Processing Record 41 of Set 13 | bouna
# City found
# Processing Record 42 of Set 13 | catamarca
# City found
# Processing Record 43 of Set 13 | dwarka
# City found
# Processing Record 44 of Set 13 | dakar
# City found
# Processing Record 45 of Set 13 | samana
# City found
# Processing Record 46 of Set 13 | santa maria do para
# City found
# Processing Record 47 of Set 13 | luzilandia
# City found
# Processing Record 48 of Set 13 | santa maria
# City found
# Processing Record 49 of Set 13 | layou
# City found
# Processing Record 50 of Set 13 | gemena
# City found
# Processing Record 1 of Set 14 | matay
# City found
# Processing Record 2 of Set 14 | anloga
# City found
# Processing Record 3 of Set 14 | kibaya
# City found
# Processing Record 4 of Set 14 | karakol
# City found
# Processing Record 5 of Set 14 | sao joao do paraiso
# City found
# Processing Record 6 of Set 14 | rodos
# City found
# Processing Record 7 of Set 14 | altay
# City found
# Processing Record 8 of Set 14 | nara
# City found
# Processing Record 9 of Set 14 | revda
# City found
# Processing Record 10 of Set 14 | plouzane
# City found
# Processing Record 11 of Set 14 | inta
# City found
# Processing Record 12 of Set 14 | luena
# City found
# Processing Record 13 of Set 14 | birao
# City found
# Processing Record 14 of Set 14 | ondjiva
# City found
# Processing Record 15 of Set 14 | lukovetskiy
# City found
# Processing Record 16 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 14 | worksop
# City found
# Processing Record 18 of Set 14 | binga
# City found
# Processing Record 19 of Set 14 | rabo de peixe
# City found
# Processing Record 20 of Set 14 | krasnoarmeysk
# City found
# Processing Record 21 of Set 14 | ndende
# City found
# Processing Record 22 of Set 14 | kang
# City found
# Processing Record 23 of Set 14 | panaba
# City found
# Processing Record 24 of Set 14 | tahta
# City found
# Processing Record 25 of Set 14 | andenes
# City found
# Processing Record 26 of Set 14 | hornepayne
# City found
# Processing Record 27 of Set 14 | mkushi
# City found
# Processing Record 28 of Set 14 | muravlenko
# City found
# Processing Record 29 of Set 14 | teguldet
# City found
# Processing Record 30 of Set 14 | baza
# City found
# Processing Record 31 of Set 14 | tahoua
# City found
# Processing Record 32 of Set 14 | sovetskiy
# City found
# Processing Record 33 of Set 14 | back mountain
# City found
# Processing Record 34 of Set 14 | igarka
# City found
# Processing Record 35 of Set 14 | shenkursk
# City found
# Processing Record 36 of Set 14 | huntington
# City found
# Processing Record 37 of Set 14 | kedougou
# City found
# Processing Record 38 of Set 14 | lipin bor
# City found
# Processing Record 39 of Set 14 | general higinio morinigo
# City found
# Processing Record 40 of Set 14 | salmas
# City found
# Processing Record 41 of Set 14 | vallenar
# City found
# Processing Record 42 of Set 14 | ndele
# City found
# Processing Record 43 of Set 14 | chabahar
# City found
# Processing Record 44 of Set 14 | gazojak
# City found
# Processing Record 45 of Set 14 | kalmunai
# City found
# Processing Record 46 of Set 14 | warrington
# City found
# Processing Record 47 of Set 14 | mehamn
# City found
# Processing Record 48 of Set 14 | brokopondo
# City found
# Processing Record 49 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 50 of Set 14 | orcopampa
# City found
# Processing Record 1 of Set 15 | gornopravdinsk
# City found
# Processing Record 2 of Set 15 | artyom
# City found
# Processing Record 3 of Set 15 | tanout
# City found
# Processing Record 4 of Set 15 | nivelles
# City found
# Processing Record 5 of Set 15 | antalaha
# City found
# Processing Record 6 of Set 15 | port hawkesbury
# City found
# Processing Record 7 of Set 15 | mbandaka
# City found
# Processing Record 8 of Set 15 | newtonmore
# City found
# Processing Record 9 of Set 15 | ancud
# City found
# Processing Record 10 of Set 15 | gazanjyk
# City found
# Processing Record 11 of Set 15 | itapua poty
# City not found. Skipping...
# Processing Record 12 of Set 15 | ogulin
# City found
# Processing Record 13 of Set 15 | rehoboth
# City found
# Processing Record 14 of Set 15 | degtyarsk
# City found
# Processing Record 15 of Set 15 | wanderlandia
# City not found. Skipping...
# Processing Record 16 of Set 15 | seydi
# City found
# Processing Record 17 of Set 15 | berea
# City found
# Processing Record 18 of Set 15 | adre
# City found
# Processing Record 19 of Set 15 | buchanan
# City found
# Processing Record 20 of Set 15 | reyes
# City found
# Processing Record 21 of Set 15 | totoral
# City found
# Processing Record 22 of Set 15 | korcula
# City found
# Processing Record 23 of Set 15 | villazon
# City found
# Processing Record 24 of Set 15 | san luis
# City found
# Processing Record 25 of Set 15 | hoganas
# City found
# Processing Record 26 of Set 15 | namikupa
# City found
# Processing Record 27 of Set 15 | cheremshan
# City found
# Processing Record 28 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 15 | chail
# City found
# Processing Record 30 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 15 | yagunovskiy
# City found
# Processing Record 32 of Set 15 | neftegorsk
# City found
# Processing Record 33 of Set 15 | kwidzyn
# City found
# Processing Record 34 of Set 15 | kapan
# City found
# Processing Record 35 of Set 15 | tromso
# City found
# Processing Record 36 of Set 15 | sabla
# City found
# Processing Record 37 of Set 15 | faro
# City found
# Processing Record 38 of Set 15 | berlevag
# City found
# Processing Record 39 of Set 15 | fez
# City found
# Processing Record 40 of Set 15 | middelburg
# City found
# Processing Record 41 of Set 15 | penzance
# City found
# Processing Record 42 of Set 15 | richards bay
# City found
# Processing Record 43 of Set 15 | filadelfia
# City found
# Processing Record 44 of Set 15 | ravar
# City found
# Processing Record 45 of Set 15 | mairana
# City found
# Processing Record 46 of Set 15 | porto novo
# City found
# Processing Record 47 of Set 15 | cauas
# City found
# Processing Record 48 of Set 15 | kudahuvadhoo
# City found
# Processing Record 49 of Set 15 | sitamau
# City found
# Processing Record 50 of Set 15 | tamayo
# City found
# Processing Record 1 of Set 16 | atbasar
# City found
# Processing Record 2 of Set 16 | calama
# City found
# Processing Record 3 of Set 16 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 16 | dalvik
# City found
# Processing Record 5 of Set 16 | aanekoski
# City found
# Processing Record 6 of Set 16 | emba
# City found
# Processing Record 7 of Set 16 | murdochville
# City found
# Processing Record 8 of Set 16 | madaoua
# City found
# Processing Record 9 of Set 16 | sodertalje
# City not found. Skipping...
# Processing Record 10 of Set 16 | chavantes
# City found
# Processing Record 11 of Set 16 | marsaxlokk
# City found
# Processing Record 12 of Set 16 | san pelayo
# City found
# Processing Record 13 of Set 16 | alytus
# City found
# Processing Record 14 of Set 16 | marienburg
# City found
# Processing Record 15 of Set 16 | constantine
# City found
# Processing Record 16 of Set 16 | kangavar
# City found
# Processing Record 17 of Set 16 | jackson
# City found
# Processing Record 18 of Set 16 | johi
# City found
# Processing Record 19 of Set 16 | mandaguari
# City found
# Processing Record 20 of Set 16 | urumqi
# City found
# Processing Record 21 of Set 16 | mogadishu
# City found
# Processing Record 22 of Set 16 | brusque
# City found
# Processing Record 23 of Set 16 | skjervoy
# City found
# Processing Record 24 of Set 16 | verkhnyaya inta
# City found
# Processing Record 25 of Set 16 | maxixe
# City found
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 724

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Deliverable 6.1.7
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Tessalit      ML  20.1986    1.0114     91.60        14
# 1              Upernavik      GL  72.7868  -56.1549     14.92        68
# 2              Cape Town      ZA -33.9258   18.4232     72.37        62
# 3  Los Llanos De Aridane      ES  28.6585  -17.9182     69.55        86
# 4           Longyearbyen      SJ  78.2186   15.6401     33.64        75
# 5                Sawakin      SD  19.1059   37.3321     84.52        71
# 6             Georgetown      MY   5.4112  100.3354     82.24        81
# 7                Qaanaaq      GL  77.4840  -69.3632      7.70        63
# 8     Comodoro Rivadavia      AR -45.8667  -67.5000     69.66        18
# 9              Carnarvon      AU -24.8667  113.6333     64.24        66
#
#    Cloudiness  Wind Speed Current Description
# 0          70       10.58       broken clouds
# 1          82        4.52       broken clouds
# 2           0        2.30           clear sky
# 3          40        9.22    scattered clouds
# 4          75        4.61       broken clouds
# 5           0        4.68           clear sky
# 6          20        0.00          few clouds
# 7          16        7.81          few clouds
# 8           0       24.16           clear sky
# 9         100       21.47     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"


# not needed because I put them in the right order to start ;), but ok
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[column_order]

#compactly
# city_data_df=city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]

# Display sample data
city_data_df.head()
# Out:
#                     City Country      Lat      Lng  Max Temp  Humidity  \
# 0               Tessalit      ML  20.1986   1.0114     91.60        14
# 1              Upernavik      GL  72.7868 -56.1549     14.92        68
# 2              Cape Town      ZA -33.9258  18.4232     72.37        62
# 3  Los Llanos De Aridane      ES  28.6585 -17.9182     69.55        86
# 4           Longyearbyen      SJ  78.2186  15.6401     33.64        75
#
#    Cloudiness  Wind Speed Current Description
# 0          70       10.58       broken clouds
# 1          82        4.52       broken clouds
# 2           0        2.30           clear sky
# 3          40        9.22    scattered clouds
# 4          75        4.61       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# # create output csv
file = '../Weather_Database/WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file,index_label = 'City_ID')
